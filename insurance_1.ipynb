# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
plt.figure(figsize=(15,10))

sns.displot(df['bmi'])

# %%
plt.figure(figsize=(15,10))

sns.kdeplot(df['bmi'])

# %%
sns.jointplot(y='bmi',x='age',data=df)

# %%
plt.figure(figsize=(15,10))

sns.displot(df.groupby(df['bmi'])['age'])

# %%
df.groupby(df['age'])['bmi'].describe()
# Out:
#      count       mean       std     min       25%      50%       75%     max
# age
# 18    69.0  31.326159  6.970188  15.960  26.18000  31.3500  36.85000  53.130
# 19    68.0  28.596912  5.859832  17.480  24.60375  28.5000  32.59250  44.880
# 20    29.0  30.632759  4.629494  21.800  28.02500  30.6850  33.00000  40.470
# 21    28.0  28.185714  6.329480  16.815  22.98250  26.8800  33.87250  39.490
# 22    28.0  31.087679  6.964901  19.950  27.03500  30.7100  35.00000  52.580
# 23    28.0  31.454464  7.303742  17.385  27.14750  32.1450  35.02000  50.380
# 24    28.0  29.142679  4.889182  20.520  25.66750  28.9000  32.18250  40.150
# 25    28.0  29.693929  6.127734  20.800  25.55125  28.0725  33.41250  45.540
# 26    28.0  29.428929  6.883321  17.195  26.22000  29.5600  32.59250  46.530
# 27    28.0  29.333571  6.481367  17.955  24.58750  30.4500  32.60625  45.900
# 28    28.0  29.482143  5.404305  17.290  25.43000  29.0700  33.50500  38.060
# ...

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.groupby(df['bmi']).describe()['charges']
# Out:
#         count          mean          std  ...          50%          75%          max
# bmi                                       ...
# 15.960    1.0   1694.796400          NaN  ...   1694.79640   1694.79640   1694.79640
# 16.815    2.0   4904.000350  2455.844784  ...   4904.00035   5772.27260   6640.54485
# 17.195    1.0  14455.644050          NaN  ...  14455.64405  14455.64405  14455.64405
# 17.290    3.0   7813.353433  4619.986089  ...   6877.98010   9853.71760  12829.45510
# 17.385    1.0   2775.192150          NaN  ...   2775.19215   2775.19215   2775.19215
# ...       ...           ...          ...  ...          ...          ...          ...
# 48.070    1.0   9432.925300          NaN  ...   9432.92530   9432.92530   9432.92530
# 49.060    1.0  11381.325400          NaN  ...  11381.32540  11381.32540  11381.32540
# 50.380    1.0   2438.055200          NaN  ...   2438.05520   2438.05520   2438.05520
# ...

# %%
plt.figure(figsize=(15,10))

sns.jointplot(x='bmi',y='charges',data=df)

# %%
df.groupby(df['age'])['charges'].mean()
# Out:
# age
# 18     7086.217556
# 19     9747.909335
# 20    10159.697736
# 21     4730.464330
# 22    10012.932802
# 23    12419.820040
# 24    10648.015962
# 25     9838.365311
# 26     6133.825309
# 27    12184.701721
# 28     9069.187564
# 29    10430.158727
# 30    12719.110358
# 31    10196.980573
# 32     9220.300291
# 33    12351.532987
# 34    11613.528121
# 35    11307.182031
# 36    12204.476138
# 37    18019.911877
# 38     8102.733674
# 39    11778.242945
# 40    11772.251310
# 41     9653.745650
# 42    13061.038669
# 43    19267.278653
# 44    15859.396587
# 45    14830.199856
# 46    14342.590639
# 47    17653.999593
# 48    14632.500445
# 49    12696.006264
# 50    15663.003301
# 51    15682.255867
# 52    18256.269719
# 53    16020.930755
# 54    18758.546475
# 55    16164.545488
# 56    15025.515837
# 57    16447.185250
# 58    13878.928112
# 59    18895.869532
# 60    21979.418507
# 61    22024.457609
# 62    19163.856573
# 63    19884.998461
# 64    23275.530837
# ...

# %%
sns.displot(df.groupby(df['age'])['charges'].mean())

# %%
plt.figure(figsize=(15,10))

sns.jointplot(x='age',y='charges',data=df)

# %%
df.groupby(df['smoker'])['charges'].describe()
# Out:
#          count          mean  ...           75%          max
# smoker                        ...
# no      1064.0   8434.268298  ...  11362.887050  36910.60803
# yes      274.0  32050.231832  ...  41019.207275  63770.42801
#
# [2 rows x 8 columns]

# %%
plt.figure(figsize=(15,10))

sns.boxplot(x='smoker',y='charges',data=df)

# %%
plt.figure(figsize=(15,10))

sns.boxplot(x='sex',y='charges',data=df)

# %%
plt.figure(figsize=(15,10))

sns.boxplot(x='children',y='charges',data=df)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn import impute
#outliers handling
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
df['bmi']=imputer.fit_transform(df[['bmi']])

# %%
imputer = SimpleImputer(strategy='mean')
df['age']=imputer.fit_transform(df[['age']])

# %%
imputer = SimpleImputer(strategy='mean')
df['charges']=imputer.fit_transform(df[['charges']])

# %%
imputer = SimpleImputer(strategy='most_frequent')
df['sex']=imputer.fit_transform(df[['sex']])

# %%
imputer = SimpleImputer(strategy='most_frequent')
df['smoker']=imputer.fit_transform(df[['smoker']])

# %%
clean = pd.get_dummies(df,columns=['sex','smoker'],drop_first=True)
clean
# Out:
#        age     bmi  children     region      charges  sex_male  smoker_yes
# 0     19.0  27.900         0  southwest  16884.92400         0           1
# 1     18.0  33.770         1  southeast   1725.55230         1           0
# 2     28.0  33.000         3  southeast   4449.46200         1           0
# 3     33.0  22.705         0  northwest  21984.47061         1           0
# 4     32.0  28.880         0  northwest   3866.85520         1           0
# ...    ...     ...       ...        ...          ...       ...         ...
# 1333  50.0  30.970         3  northwest  10600.54830         1           0
# 1334  18.0  31.920         0  northeast   2205.98080         0           0
# 1335  18.0  36.850         0  southeast   1629.83350         0           0
# 1336  21.0  25.800         0  southwest   2007.94500         0           0
# 1337  61.0  29.070         0  northwest  29141.36030         0           1
#
# [1338 rows x 7 columns]

# %%
clean.drop('region',axis=1,inplace=True)
clean.head()
# Out:
#     age     bmi  children      charges  sex_male  smoker_yes
# 0  19.0  27.900         0  16884.92400         0           1
# 1  18.0  33.770         1   1725.55230         1           0
# 2  28.0  33.000         3   4449.46200         1           0
# 3  33.0  22.705         0  21984.47061         1           0
# 4  32.0  28.880         0   3866.85520         1           0

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         1338 non-null   float64
#  1   bmi         1338 non-null   float64
#  2   children    1338 non-null   int64
#  3   charges     1338 non-null   float64
#  4   sex_male    1338 non-null   uint8
#  5   smoker_yes  1338 non-null   uint8
# dtypes: float64(3), int64(1), uint8(2)
# memory usage: 44.6 KB

# %%
x=clean.drop('charges',axis=1)
y=clean['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
(x_train,x_test,y_train,y_test)=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


models = {
    'LR': LinearRegression(),
    'SVM': SVR(),
    'KNN': KNeighborsRegressor(),
    'DT': DecisionTreeRegressor(),
    'RF': RandomForestRegressor(),
    'XGB': XGBRegressor()
}


for name, model in models.items():
    print(f"Model: {name}")
    print("-"*20)
    model.fit(x_train, y_train)
    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)
    print(f"Train MAE: {mean_absolute_error(y_train, y_pred_train)}")
    print(f"Test MAE: {mean_absolute_error(y_test, y_pred_test)}")
    print(f"Train RMSE: {np.sqrt(mean_squared_error(y_train, y_pred_train))}")
    print(f"Test RMSE: {np.sqrt(mean_squared_error(y_test, y_pred_test))}")
    print(f"Train R2: {r2_score(y_train, y_pred_train)}")
    print(f"Test R2: {r2_score(y_test, y_pred_test)}")
    print("\n")
# Out:
# Model: LR
# --------------------
# Train MAE: 4223.484977552596
# Test MAE: 4048.203698086808
# Train RMSE: 6116.104269400224
# Test RMSE: 5816.338250925481
# Train R2: 0.7519601111918398
# Test R2: 0.7381253691785852
#
#
# Model: SVM
# --------------------
# Train MAE: 8435.701999303157
# Test MAE: 7786.473119365441
# Train RMSE: 12920.53392006928
# Test RMSE: 11856.97379667588
# Train R2: -0.10696193597413095
# Test R2: -0.08828298219373565
#
#
# Model: KNN
# --------------------
# Train MAE: 6345.086665241869
# Test MAE: 7119.2721661485075
# Train RMSE: 9420.15258862864
# Test RMSE: 9948.043482385443
# Train R2: 0.4115797074834914
# Test R2: 0.23392821437265598
#
#
# Model: DT
# --------------------
# Train MAE: 29.572515327102803
# Test MAE: 2489.7046198134335
# Train RMSE: 494.20598375812835
# Test RMSE: 5742.142590457757
# Train R2: 0.9983804745940406
# Test R2: 0.7447639214691757
#
#
# Model: RF
# --------------------
# Train MAE: 1037.1887222550408
# ...
